# %% [markdown]
# # The Sparsification Lab Notebook

# %% [markdown]
# #### Imports

# %%
from networkit import *
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import pickle
from scipy import stats

# %%
# %matplotlib inline

# %% [markdown]
# #### Helper Functions

# %%
def calcEdgeScores(G, methods):
    """ Calculates edge scores for given methods and returns a DataFrame """
    data = {}
    for (methodName, (methodClass, kwargs)) in methods.items():
        if "G" in kwargs:
            kwargs["G"] = G
        print(methodClass)
        method = methodClass(**kwargs)
        print("calculating {0}{1}".format(methodName, kwargs)); sys.stdout.flush()
        # %time data[methodName] = method.getAttribute(G)
    return pd.DataFrame(data)

# %%
def status(message):
    """print status message """
    print(message); sys.stdout.flush()

# %% [markdown]
# #### Plotting Functions

# %%
def plotScoreCorrelations(attributeData, figsize=(8,8), method="spearman"):
    """ Draws a seaborn correlation matrix plot """
    cmap = sns.diverging_palette(220, 20, as_cmap=True)
    f, ax = plt.subplots(figsize=figsize)
    status("correlating")
    sns.corrplot(attributeData, cmap=cmap, method=method)
    f.tight_layout()

# %%
def plotScoreDistributions(G, methods, attributeData):
    """ Scatterplots distribution of scores """
    for (methodName, _) in methods.items():
        plt.figure(figsize=(6,2))
        plt.xlim((0,G.numberOfEdges()))
        plt.scatter(np.arange(0, G.numberOfEdges()), attributeData[methodName], s=0.1)
        plt.xlabel(methodName)

# %%
# I stole this code out of seaborn and hacked it

def symmatplot(mat, p_mat=None, names=None, cmap="Greys", cmap_range=None,
               cbar=True, annot=True, diag_names=True, ax=None, **kwargs):
    """Plot a symmetric matrix with colormap and statistic values."""
    
    def sig_stars(p):
        """Return a R-style significance string corresponding to p values."""
        if p < 0.001:
            return "***"
        elif p < 0.01:
            return "**"
        elif p < 0.05:
            return "*"
        elif p < 0.1:
            return "."
        return ""
    
    if ax is None:
        ax = plt.gca()

    nvars = len(mat)
    if isinstance(mat, pd.DataFrame):
        plotmat = mat.values.copy()
        mat = mat.values
    else:
        plotmat = mat.copy()
    plotmat[np.triu_indices(nvars)] = np.nan

    if cmap_range is None:
        vmax = np.nanmax(plotmat) * 1.15
        vmin = np.nanmin(plotmat) * 1.15
    elif len(cmap_range) == 2:
        vmin, vmax = cmap_range
    else:
        raise ValueError("cmap_range argument not understood")

    mat_img = ax.matshow(plotmat, cmap=cmap, vmin=vmin, vmax=vmax, **kwargs)

    if cbar:
        plt.colorbar(mat_img, shrink=.75)

    if p_mat is None:
        p_mat = np.ones((nvars, nvars))

    if annot:
        for i, j in zip(*np.triu_indices(nvars, 1)):
            val = mat[i, j]
            stars = sig_stars(p_mat[i, j])
            ax.text(j, i, "\n%.2g\n%s" % (val, stars),
                    fontdict=dict(ha="center", va="center"))
    else:
        fill = np.ones_like(plotmat)
        fill[np.tril_indices_from(fill, -1)] = np.nan
        ax.matshow(fill, cmap="Greys", vmin=0, vmax=0, zorder=2)

    if names is None:
        names = ["var%d" % i for i in range(nvars)]

    if diag_names:
        for i, name in enumerate(names):
            ax.text(i, i, name, fontdict=dict(ha="center", va="center",
                                              weight="bold", rotation=45))
        ax.set_xticklabels(())
        ax.set_yticklabels(())
    else:
        ax.xaxis.set_ticks_position("bottom")
        xnames = names if annot else names[:-1]
        ax.set_xticklabels(xnames, rotation=90)
        ynames = names if annot else names[1:]
        ax.set_yticklabels(ynames)

    minor_ticks = np.linspace(-.5, nvars - 1.5, nvars)
    ax.set_xticks(minor_ticks, True)
    ax.set_yticks(minor_ticks, True)
    major_ticks = np.linspace(0, nvars - 1, nvars)
    xticks = major_ticks if annot else major_ticks[:-1]
    ax.set_xticks(xticks)
    yticks = major_ticks if annot else major_ticks[1:]
    ax.set_yticks(yticks)
    ax.grid(False, which="major")
    ax.grid(True, which="minor", linestyle="-")

    return ax


def aggregateCorrPlot(corrmat, names=None, annot=True, sig_stars=True, sig_tail="both",
             sig_corr=True, cmap=None, cmap_range=None, cbar=True,
             diag_names=True, method=None, ax=None, **kwargs):
    """Plot a correlation matrix with colormap and r values.

    Parameters
    ----------
    corrmat : DataFrame
        correlation matrix
    names : sequence of strings
        Names to associate with variables if `data` is not a DataFrame.
    annot : bool
        Whether to annotate the upper triangle with correlation coefficients.
    sig_stars : bool
        If True, get significance with permutation test and denote with stars.
    sig_tail : both | upper | lower
        Direction for significance test. Also controls the default colorbar.
    sig_corr : bool
        If True, use FWE-corrected p values for the sig stars.
    cmap : colormap
        Colormap name as string or colormap object.
    cmap_range : None, "full", (low, high)
        Either truncate colormap at (-max(abs(r)), max(abs(r))), use the
        full range (-1, 1), or specify (min, max) values for the colormap.
    cbar : bool
        If true, plot the colorbar legend.
    method: None (pearson) | kendall | spearman
        Correlation method to compute pairwise correlations. Methods other
        than the default pearson correlation will not have a significance
        computed.
    ax : matplotlib axis
        Axis to draw plot in.
    kwargs : other keyword arguments
        Passed to ax.matshow()

    Returns
    -------
    ax : matplotlib axis
        Axis object with plot.

    """
    

    # Pandas will drop non-numeric columns; let's keep track of that operation
    names = corrmat.columns
    #data = data[names]

    # Get p values with a permutation test
    #if annot and sig_stars and method is None:
     #   p_mat = algo.randomize_corrmat(data.values.T, sig_tail, sig_corr)
    #else:
    p_mat = None

    # Sort out the color range
    if cmap_range is None:
        triu = np.triu_indices(len(corrmat), 1)
        vmax = min(1, np.max(np.abs(corrmat.values[triu])) * 1.15)
        vmin = -vmax
        if sig_tail == "both":
            cmap_range = vmin, vmax
        elif sig_tail == "upper":
            cmap_range = 0, vmax
        elif sig_tail == "lower":
            cmap_range = vmin, 0
    elif cmap_range == "full":
        cmap_range = (-1, 1)

    # Find a colormapping, somewhat intelligently
    if cmap is None:
        if min(cmap_range) >= 0:
            cmap = "OrRd"
        elif max(cmap_range) <= 0:
            cmap = "PuBu_r"
        else:
            cmap = "coolwarm"
    if cmap == "jet":
        # Paternalism
        raise ValueError("Never use the 'jet' colormap!")

    # Plot using the more general symmatplot function
    ax = symmatplot(corrmat, p_mat, names, cmap, cmap_range,
                    cbar, annot, diag_names, ax, **kwargs)

    return ax

# %% [markdown]
# #### Sparsification Methods

# %%
# short name -> class, constructor kwargs
methods = {"Random": (sparsification.RandomBackbone, {}),
            "SimmelianNP" : (sparsification.SimmelianBackboneNonParametric, {}),
            "SimmelianP" : (sparsification.SimmelianBackboneParametric, {"maxRank": 10}),
            "SimmelianMS" : (sparsification.SimmelianMultiscaleBackbone, {}),
            "ForestFire" : (sparsification.ForestFireBackbone, {"burnProbability": 0.5, "targetBurntRatio" : 5.0}),
            "LocalSim" : (sparsification.LocalSimilarityBackbone, {}),
            "LocalDegree" : (sparsification.LocalDegreeBackbone, {}),
            "Modularity" : (sparsification.ModularityPartitionAttributizer, {}),
            #"Const" : (sparsification.ConstantAttributizer, {"constValue" : 1.0}),
            "Triangles" : (sparsification.TriangleBackbone, {})
            }

# %% [markdown]
# #### The Network Collection

# %%
cd ~/workspace/Data/Graphs/Facebook
# Out:
# /Users/cls/workspace/Data/Graphs/Facebook

# %%
G = readGraph("fb-Caltech36.edgelist", Format.EdgeListTabZero)
G.indexEdges()

# %% [markdown]
# #### Precalculation of Edge Scores

# %%
edgeAttributes = calcEdgeScores(G, methods)
# Out:
# <class 'networkit.sparsification.LocalSimilarityBackbone'>
# calculating LocalSim{}
# CPU times: user 9.65 ms, sys: 3.96 ms, total: 13.6 ms
# Wall time: 12.3 ms
# <class 'networkit.sparsification.ForestFireBackbone'>
# calculating ForestFire{'targetBurntRatio': 5.0, 'burnProbability': 0.5}
# CPU times: user 158 ms, sys: 6.64 ms, total: 164 ms
# Wall time: 164 ms
# <class 'networkit.sparsification.SimmelianBackboneParametric'>
# calculating SimmelianP{'maxRank': 10}
# CPU times: user 161 ms, sys: 1.87 ms, total: 163 ms
# Wall time: 75.4 ms
# <class 'networkit.sparsification.TriangleBackbone'>
# calculating Triangles{}
# CPU times: user 7.16 ms, sys: 450 µs, total: 7.61 ms
# Wall time: 3.91 ms
# <class 'networkit.sparsification.SimmelianMultiscaleBackbone'>
# calculating SimmelianMS{}
# CPU times: user 6.01 ms, sys: 630 µs, total: 6.64 ms
# Wall time: 6.7 ms
# <class 'networkit.sparsification.ModularityPartitionAttributizer'>
# calculating Modularity{}
# CPU times: user 18 ms, sys: 3.27 ms, total: 21.2 ms
# Wall time: 20.9 ms
# <class 'networkit.sparsification.SimmelianBackboneNonParametric'>
# calculating SimmelianNP{}
# CPU times: user 1.13 s, sys: 3.22 ms, total: 1.13 s
# Wall time: 513 ms
# <class 'networkit.sparsification.RandomBackbone'>
# calculating Random{}
# CPU times: user 878 µs, sys: 56 µs, total: 934 µs
# Wall time: 944 µs
# <class 'networkit.sparsification.LocalDegreeBackbone'>
# calculating LocalDegree{}
# CPU times: user 3.33 ms, sys: 71 µs, total: 3.41 ms
# Wall time: 3.42 ms

# %% [markdown]
# #### Score Distributions

# %%
plotScoreDistributions(G, methods, edgeAttributes)

# %% [markdown]
# ### Correlation of Edge Scores

# %%
plotScoreCorrelations(edgeAttributes, method="spearman")
plt.savefig("/Users/cls/Downloads/corr-spearman.pdf", bbox_inches="tight")
# Out:
# correlating

# %% [markdown]
# #### aggregate over multiple networks

# %%
fbGraphPaths = !ls /Users/cls/workspace/Data/Graphs/Facebook/*.edgelist

# %%
fbGraphPathsSmall = fbGraphPaths[:1]

# %%
graphs = [readGraph(path, Format.EdgeListTabZero) for path in fbGraphPathsSmall]
for G in graphs:
    G.indexEdges()
graphs.sort(key=lambda G: G.numberOfEdges())
#graphs = graphs[:]

# %%
def aggregateEdgeScoreCorrelations(graphs, methods):
    nGraphs = len(graphs)
    corrMat = None
    for G in graphs:
        status("")
        status("{0} {1}".format(G, properties.size(G)))
        edgeScores = calcEdgeScores(G, methods)
        if corrMat is not None:
            corrMat = edgeScores.corr(method="spearman") + corrMat
        else:
            corrMat = edgeScores.corr(method="spearman")
    corrMat = corrMat / nGraphs
    status("done")
    return corrMat

# %%
aggrCorr = aggregateEdgeScoreCorrelations(graphs, methods)
# Out:
# <_NetworKit.Graph object at 0x10f8799d0> (6386, 217662)
# <class 'networkit.sparsification.LocalSimilarityBackbone'>
# calculating LocalSim{}
# CPU times: user 148 ms, sys: 29.9 ms, total: 178 ms
# Wall time: 146 ms
# <class 'networkit.sparsification.ForestFireBackbone'>
# calculating ForestFire{'targetBurntRatio': 5.0, 'burnProbability': 0.5}
# CPU times: user 2.05 s, sys: 10.4 ms, total: 2.06 s
# Wall time: 2.06 s
# <class 'networkit.sparsification.SimmelianBackboneParametric'>
# calculating SimmelianP{'maxRank': 10}
# CPU times: user 2.16 s, sys: 14.9 ms, total: 2.17 s
# Wall time: 879 ms
# <class 'networkit.sparsification.TriangleBackbone'>
# calculating Triangles{}
# CPU times: user 175 ms, sys: 3.07 ms, total: 178 ms
# Wall time: 73.6 ms
# <class 'networkit.sparsification.SimmelianMultiscaleBackbone'>
# calculating SimmelianMS{}
# CPU times: user 135 ms, sys: 8.74 ms, total: 144 ms
# Wall time: 144 ms
# <class 'networkit.sparsification.ModularityPartitionAttributizer'>
# calculating Modularity{}
# CPU times: user 269 ms, sys: 27.9 ms, total: 297 ms
# Wall time: 275 ms
# <class 'networkit.sparsification.SimmelianBackboneNonParametric'>
# calculating SimmelianNP{}
# CPU times: user 38.3 s, sys: 73 ms, total: 38.4 s
# Wall time: 15.1 s
# <class 'networkit.sparsification.RandomBackbone'>
# calculating Random{}
# CPU times: user 7.13 ms, sys: 2.36 ms, total: 9.49 ms
# Wall time: 9.5 ms
# <class 'networkit.sparsification.LocalDegreeBackbone'>
# calculating LocalDegree{}
# CPU times: user 36.1 ms, sys: 3.4 ms, total: 39.5 ms
# Wall time: 39.5 ms
# done

# %%
aggrCorr
# Out:
#              ForestFire  LocalDegree  LocalSim  Modularity    Random  \
# ForestFire     1.000000    -0.461142  0.105728    0.092499  0.000653
# LocalDegree   -0.461142     1.000000 -0.237021   -0.127928 -0.000197
# LocalSim       0.105728    -0.237021  1.000000    0.385670  0.000953
# Modularity     0.092499    -0.127928  0.385670    1.000000  0.003647
# Random         0.000653    -0.000197  0.000953    0.003647  1.000000
# SimmelianMS   -0.601804     0.837782 -0.210418   -0.166759  0.000652
# SimmelianNP   -0.014072    -0.144992  0.778257    0.442239  0.002685
# SimmelianP     0.047979    -0.161634  0.695886    0.421098  0.003362
# Triangles     -0.367629     0.204456  0.575731    0.233564  0.002790
#
#              SimmelianMS  SimmelianNP  SimmelianP  Triangles
# ForestFire     -0.601804    -0.014072    0.047979  -0.367629
# LocalDegree     0.837782    -0.144992   -0.161634   0.204456
# LocalSim       -0.210418     0.778257    0.695886   0.575731
# Modularity     -0.166759     0.442239    0.421098   0.233564
# Random          0.000652     0.002685    0.003362   0.002790
# SimmelianMS     1.000000    -0.057720   -0.122338   0.447977
# SimmelianNP    -0.057720     1.000000    0.851084   0.685795
# SimmelianP     -0.122338     0.851084    1.000000   0.503924
# Triangles       0.447977     0.685795    0.503924   1.000000

# %%
f, ax = plt.subplots(figsize=(8,8))
aggregateCorrPlot(aggrCorr, cmap=sns.diverging_palette(220, 20, as_cmap=True))
f.tight_layout()

# %% [markdown]
# ## Algorithm Speedups

# %% [markdown]
# ### Are betweenness scores preserved when sparsifying with LocalDegree?

# %%
G = readGraph("../Facebook/fb-Caltech36.edgelist", Format.EdgeListTabZero)
G.indexEdges()

# %%
properties.size(G)
# Out:
# (769, 16656)

# %%
bc = centrality.Betweenness(G, normalized=True)
bc.run()

# %%
bc.ranking()[:10]
# Out:
# [(708, 0.047078831164634904),
#  (222, 0.04257937943016091),
#  (277, 0.030392410234729654),
#  (89, 0.028808745675464497),
#  (354, 0.021883909607909223),
#  (734, 0.021448262736549182),
#  (637, 0.018346832070485618),
#  (663, 0.01829459897551756),
#  (264, 0.017671353768869653),
#  (84, 0.014274830088887682)]

# %%
localDegree = sparsification.LocalDegreeBackbone()
rand = sparsification.RandomBackbone()

# %%
edgeRatio = 0.1
Gs = localDegree.getSparsifiedGraph(G, localDegree.getParameter(G, edgeRatio))
Gr = rand.getSparsifiedGraph(G, rand.getParameter(G, edgeRatio))

# %%
print(properties.size(G))
print(properties.size(Gs))
print(properties.size(Gr))
# Out:
# (769, 16656)
# (769, 1666)
# (769, 1663)

# %%
bcLocalDegree = centrality.Betweenness(Gs, normalized=True)

# %%
bcLocalDegree.run()

# %%
bcRandom = centrality.Betweenness(Gr, normalized=True)
bcRandom.run()

# %%
plt.plot(centrality.relativeRankError(bc.ranking(), bcRandom.ranking()))

# %%
plt.plot(centrality.relativeRankError(bc.ranking(), bcLocalDegree.ranking()))

# %%
stats.gmean(centrality.relativeRankError(bc.ranking(), bcLocalDegree.ranking()))
# Out:
# 1.1689332190262411

# %%
stats.gmean(centrality.relativeRankError(bc.ranking(), bcRandom.ranking()))
# Out:
# 1.0627922723903902
