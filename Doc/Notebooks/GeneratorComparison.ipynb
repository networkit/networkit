# %%
from networkit import *
import math
import random
import sys

scale=16
n = 2**scale
targetM = min(n * 60,n*n)
initialConnected = max(targetM/n,10)
degreeSequenceExponent = 1.35
setLogLevel("DEBUG")

#prepare degree sequences for chunglu and havel-hakimi

frequencies = []
for i in range(1,int(n/2)):
    frequencies.append((i**(-degreeSequenceExponent)))

# %%
nodes = sum(frequencies)
degrees = []
for i in range(0,len(frequencies)):
    frequencies[i] *= n / nodes
    rest = frequencies[i] - math.floor(frequencies[i])
    rest = int(random.random() < rest)
    frequencies[i] = math.floor(frequencies[i]) + rest
    for k in range(0,int(frequencies[i])):
        degrees.append(i)
        
if (n - frequencies[0]) <= frequencies[len(frequencies)-1]:
    print('Not even enough nodes for the highest-degree node to connect to!')

edges = sum(degrees)/2
factor = targetM / edges
for i in range(0,len(degrees)):
    degrees[i] = math.floor(factor*degrees[i])
    
if sum(degrees) % 2 != 0:
    degrees[len(degrees)-1] += 1
    
R = math.acosh(n/(2*math.pi)+1)
targetR = 2*math.log(8*n / (math.pi*(targetM/n)*2))
print('Stretch:', targetR / R)

genlist = []
genlist.append(generators.RmatGenerator(scale,targetM / n, 0.6,0.1,0.1,0.2))
genlist.append(generators.DorogovtsevMendesGenerator(targetM/2))
genlist.append(generators.HyperbolicGenerator(n,1,1,targetR / R))
genlist.append(generators.ChungLuGenerator(degrees))
genlist.append(generators.BarabasiAlbertGenerator(targetM / n,n,initialConnected)) # too slow
#genlist.append(generators.HavelHakimiGenerator(degrees)) # complains about degree Sequence
# Out:
# Stretch: 1.4554148254506505

# %%
print('Degree sequence implies ', len(degrees), 'nodes and ', sum(degrees)/2, ' edges. TargetM was ', targetM)
if generators.HavelHakimiGenerator(degrees).isRealizable():
    print("HavelHakimi considers it realizable.")
else:
    print("HavelHakimi considers it not realizable.")
# Out:
# Degree sequence implies  65488 nodes and  3920550.0  edges. TargetM was  3932160
# HavelHakimi considers it not realizable.

# %%
for gen in genlist:
    print('Starting run with',gen.__class__, ' and ' ,n,'nodes')
    sys.stdout.flush()
    # %time G = gen.generate()
    print(G.numberOfEdges())
    # %time properties.overview(G)
# Out:
# Starting run with <class '_NetworKit.RmatGenerator'>  and  65536 nodes
# CPU times: user 4.84 s, sys: 32.9 ms, total: 4.87 s
# Wall time: 4.86 s
# 2823398
# Network Properties: G#5
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65536
# edges (m)                      2823398
# directed?                      False
# weighted?                      True
# isolated nodes                 1550
# self-loops                     20494
# density                        0.001315
# clustering coefficient         0.046426
# degeneracy (max. core number)  219
# -----------------------------  --------
# Node Degree Properties
# -------------------------  --------------
# min. degree                0
# max. degree                3775
# avg. degree                85.850555
# degree power law fit?      True, 2.797691
# degree power law exponent  1.5351
# degree assortativity       0.1666
# -------------------------  --------------
# Path Structure
# -------------------------  -------
# connected components       1588
# size of largest component  63918
# estimated diameter range   (9, 10)
# -------------------------  -------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  1609
#                                              modularity   0.328328
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇56361.00
# 152- :  ▇▇▇▇5228.00
# 304- :  ▇1430.00
# 456- :  ▇1785.00
# 608- :  |  35.00
# 760- :  |   0.00
# 912- :  | 558.00
# 1064-:  |   2.00
# 1216-:  |   0.00
# 1368-:  |   0.00
# 1520-:  | 106.00
# 1672-:  |  14.00
# 1824-:  |   0.00
# 1976-:  |   0.00
# 2128-:  |   0.00
# 2280-:  |   0.00
# 2432-:  |  13.00
# 2584-:  |   3.00
# 2736-:  |   0.00
# 2888-:  |   0.00
# 3040-:  |   0.00
# 3192-:  |   0.00
# 3344-:  |   0.00
# 3496-:  |   0.00
# 3648-:  |   1.00
#
# CPU times: user 13.5 s, sys: 144 ms, total: 13.7 s
# Wall time: 10.6 s
# Starting run with <class '_NetworKit.DorogovtsevMendesGenerator'>  and  65536 nodes
# CPU times: user 1.73 s, sys: 28 ms, total: 1.76 s
# Wall time: 1.76 s
# 3932157
# Network Properties: G#19
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      1966080
# edges (m)                      3932157
# directed?                      False
# weighted?                      False
# isolated nodes                 0
# self-loops                     0
# density                        0.000002
# clustering coefficient         0.694780
# degeneracy (max. core number)  2
# -----------------------------  --------
# Node Degree Properties
# -------------------------  --------------
# min. degree                2
# max. degree                313
# avg. degree                3.999997
# degree power law fit?      True, 6.767059
# degree power law exponent  1.2825
# degree assortativity       0.0494
# -------------------------  --------------
# Path Structure
# -------------------------  --------
# connected components       1
# size of largest component  1966080
# estimated diameter range   (32, 34)
# -------------------------  --------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  824
#                                              modularity   0.996868
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇1909887.00
# 13-  :  ▇49451.00
# 26-  :  |5208.00
# 39-  :  |1011.00
# 52-  :  | 312.00
# 65-  :  | 128.00
# 78-  :  |  43.00
# 91-  :  |  16.00
# 104- :  |  10.00
# 117- :  |   4.00
# 130- :  |   4.00
# 143- :  |   3.00
# 156- :  |   1.00
# 169- :  |   1.00
# 182- :  |   0.00
# 195- :  |   0.00
# 208- :  |   0.00
# 221- :  |   0.00
# 234- :  |   0.00
# 247- :  |   0.00
# 260- :  |   0.00
# 273- :  |   0.00
# 286- :  |   0.00
# 299- :  |   0.00
# 312- :  |   1.00
#
# CPU times: user 33.6 s, sys: 356 ms, total: 34 s
# Wall time: 18.2 s
# Starting run with <class '_NetworKit.HyperbolicGenerator'>  and  65536 nodes
# CPU times: user 2.76 s, sys: 43.9 ms, total: 2.81 s
# Wall time: 1.36 s
# 4001725
# Network Properties: G#45
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65536
# edges (m)                      4001725
# directed?                      False
# weighted?                      False
# isolated nodes                 0
# self-loops                     0
# density                        0.001863
# clustering coefficient         0.794580
# degeneracy (max. core number)  84
# -----------------------------  --------
# Node Degree Properties
# -------------------------  ---------------
# min. degree                38
# max. degree                14916
# avg. degree                122.122955
# degree power law fit?      True, 16.841530
# degree power law exponent  1.5024
# degree assortativity       -0.0183
# -------------------------  ---------------
# Path Structure
# -------------------------  ------
# connected components       1
# size of largest component  65536
# estimated diameter range   (4, 4)
# -------------------------  ------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  25
#                                              modularity   0.897970
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇64808.00
# 597- :  | 555.00
# 1194-:  |  97.00
# 1791-:  |  33.00
# 2388-:  |  14.00
# 2985-:  |   9.00
# 3582-:  |   4.00
# 4179-:  |   3.00
# 4776-:  |   3.00
# 5373-:  |   1.00
# 5970-:  |   2.00
# 6567-:  |   0.00
# 7164-:  |   0.00
# 7761-:  |   1.00
# 8358-:  |   1.00
# 8955-:  |   0.00
# 9552-:  |   0.00
# 10149-:  |   1.00
# 10746-:  |   0.00
# 11343-:  |   0.00
# 11940-:  |   1.00
# 12537-:  |   0.00
# 13134-:  |   0.00
# 13731-:  |   0.00
# 14328-:  |   3.00
#
# CPU times: user 14.1 s, sys: 196 ms, total: 14.3 s
# Wall time: 7.41 s
# Starting run with <class '_NetworKit.ChungLuGenerator'>  and  65536 nodes
# CPU times: user 44.1 s, sys: 6.99 ms, total: 44.1 s
# Wall time: 44.1 s
# 2705210
# Network Properties: G#59
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65488
# edges (m)                      2705210
# directed?                      False
# weighted?                      False
# isolated nodes                 36892
# self-loops                     0
# density                        0.001262
# clustering coefficient         0.643881
# degeneracy (max. core number)  932
# -----------------------------  --------
# Node Degree Properties
# -------------------------  --------------
# min. degree                0
# max. degree                4082
# avg. degree                82.616968
# degree power law fit?      True, 3.204262
# degree power law exponent  1.7796
# degree assortativity       -0.2983
# -------------------------  --------------
# Path Structure
# -------------------------  ------
# connected components       36894
# size of largest component  28594
# estimated diameter range   (5, 6)
# -------------------------  ------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  36902
#                                              modularity   0.044208
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇60788.00
# 164- :  ▇1333.00
# 328- :  | 671.00
# 492- :  | 395.00
# 656- :  | 281.00
# 820- :  | 270.00
# 984- :  | 210.00
# 1148-:  | 190.00
# 1312-:  | 153.00
# 1476-:  | 138.00
# 1640-:  | 113.00
# 1804-:  | 122.00
# 1968-:  |  97.00
# 2132-:  | 106.00
# 2296-:  |  78.00
# 2460-:  |  76.00
# 2624-:  |  64.00
# 2788-:  |  63.00
# 2952-:  |  55.00
# 3116-:  |  50.00
# 3280-:  |  50.00
# 3444-:  |  60.00
# 3608-:  |  47.00
# 3772-:  |  58.00
# 3936-:  |  20.00
#
# CPU times: user 14.7 s, sys: 188 ms, total: 14.9 s
# Wall time: 9.37 s
# Starting run with <class '_NetworKit.BarabasiAlbertGenerator'>  and  65536 nodes
# CPU times: user 1min 34s, sys: 31.2 ms, total: 1min 34s
# Wall time: 1min 34s
# 3928619
# Network Properties: G#70
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65536
# edges (m)                      3928619
# directed?                      False
# weighted?                      False
# isolated nodes                 0
# self-loops                     0
# density                        0.001829
# clustering coefficient         0.007774
# degeneracy (max. core number)  60
# -----------------------------  --------
# Node Degree Properties
# -------------------------  ---------------
# min. degree                60
# max. degree                3223
# avg. degree                119.891937
# degree power law fit?      True, 16.115372
# degree power law exponent  1.5311
# degree assortativity       0.0010
# -------------------------  ---------------
# Path Structure
# -------------------------  ------
# connected components       1
# size of largest component  65536
# estimated diameter range   (3, 4)
# -------------------------  ------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  9
#                                              modularity   0.075463
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇51172.00
# 129- :  ▇▇▇▇▇▇▇▇▇▇10712.00
# 258- :  ▇1975.00
# 387- :  | 674.00
# 516- :  | 370.00
# 645- :  | 168.00
# 774- :  | 111.00
# 903- :  |  72.00
# 1032-:  |  55.00
# 1161-:  |  45.00
# 1290-:  |  49.00
# 1419-:  |  23.00
# 1548-:  |  24.00
# 1677-:  |  12.00
# 1806-:  |  13.00
# 1935-:  |  14.00
# 2064-:  |   4.00
# 2193-:  |   7.00
# 2322-:  |   6.00
# 2451-:  |   4.00
# 2580-:  |  11.00
# 2709-:  |   9.00
# 2838-:  |   2.00
# 2967-:  |   3.00
# 3096-:  |   1.00
#
# CPU times: user 20.6 s, sys: 188 ms, total: 20.8 s
# Wall time: 11.5 s

# %%
deg_sum = 0
for j in range(0,len(degrees)):
    deg_sum += degrees[j]
    min_deg_sum = 0
    for i in range(j+1,len(degrees)):
        min_deg_sum += min(degrees[i], j+1)
    #print(deg_sum, ', ', min_deg_sum)
    if (deg_sum > (j+1) * j + min_deg_sum):
        print('Not realizable at', j, ', because ', deg_sum, ' > ', j+1,'*',j,' + ', min_deg_sum)
