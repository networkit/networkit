# %%
from networkit import *
import math
import random
import sys

scale=16
n = 2**scale
targetM = min(n * 60,n*n)
initialConnected = max(targetM/n,10)
degreeSequenceExponent = 1.35
setLogLevel("DEBUG")

#prepare degree sequences for chunglu and havel-hakimi

frequencies = []
for i in range(1,int(n/2)):
    frequencies.append((i**(-degreeSequenceExponent)))

# %%
nodes = sum(frequencies)
degrees = []
for i in range(0,len(frequencies)):
    frequencies[i] *= n / nodes
    rest = frequencies[i] - math.floor(frequencies[i])
    rest = int(random.random() < rest)
    frequencies[i] = math.floor(frequencies[i]) + rest
    for k in range(0,int(frequencies[i])):
        degrees.append(i)
        
if (n - frequencies[0]) <= frequencies[len(frequencies)-1]:
    print('Not even enough nodes for the highest-degree node to connect to!')

edges = sum(degrees)/2
factor = targetM / edges
for i in range(0,len(degrees)):
    degrees[i] = math.floor(factor*degrees[i])
    
if sum(degrees) % 2 != 0:
    degrees[len(degrees)-1] += 1
    
R = math.acosh(n/(2*math.pi)+1)
targetR = 2*math.log(8*n / (math.pi*(targetM/n)*2))
print('Stretch:', targetR / R)

genlist = []
genlist.append(generators.RmatGenerator(scale,targetM / n, 0.7,0.1,0.01,0.3))
genlist.append(generators.DorogovtsevMendesGenerator(targetM/2))
genlist.append(generators.HyperbolicGenerator(n,1,1,targetR / R))
genlist.append(generators.ChungLuGenerator(degrees))
genlist.append(generators.BarabasiAlbertGenerator(targetM / n,n,initialConnected)) # too slow
#genlist.append(generators.HavelHakimiGenerator(degrees)) # complains about degree Sequence
# Out:
# Stretch: 1.4554148254506505

# %%
print('Degree sequence implies ', len(degrees), 'nodes and ', sum(degrees)/2, ' edges. TargetM was ', targetM)
if generators.HavelHakimiGenerator(degrees).isRealizable():
    print("HavelHakimi considers it realizable.")
else:
    print("HavelHakimi considers it not realizable.")
# Out:
# Degree sequence implies  65572 nodes and  3920997.0  edges. TargetM was  3932160
# HavelHakimi considers it not realizable.

# %%
for gen in genlist:
    print('Starting run with',gen.__class__, ' and ' ,n,'nodes')
    sys.stdout.flush()
    # %time G = gen.generate()
    print(G.numberOfEdges())
    # %time properties.overview(G)
# Out:
# Starting run with <class '_NetworKit.RmatGenerator'>  and  65536 nodes
# CPU times: user 3.04 s, sys: 36.1 ms, total: 3.08 s
# Wall time: 3.07 s
# 1278943
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# <_NetworKit.PLM object at 0x7f4301108cb0>
# Network Properties: G#2
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65536
# edges (m)                      1278943
# directed?                      False
# weighted?                      True
# isolated nodes                 4654
# self-loops                     28927
# density                        0.000596
# clustering coefficient         0.142231
# degeneracy (max. core number)  77
# -----------------------------  --------
# Node Degree Properties
# -------------------------  ---------------
# min. degree                0
# max. degree                5930
# avg. degree                38.588852
# degree power law fit?      True, 10.618375
# degree power law exponent  1.3691
# degree assortativity       0.0272
# -------------------------  ---------------
# Path Structure
# -------------------------  -------
# connected components       4752
# size of largest component  60736
# estimated diameter range   (9, 10)
# -------------------------  -------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  4760
#                                              modularity   0.500347
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇64026.00
# 238- :  | 813.00
# 476- :  | 560.00
# 714- :  |   0.00
# 952- :  |   1.00
# 1190-:  | 119.00
# 1428-:  |   0.00
# 1666-:  |   0.00
# 1904-:  |   0.00
# 2142-:  |   0.00
# 2380-:  |   0.00
# 2618-:  |  12.00
# 2856-:  |   4.00
# 3094-:  |   0.00
# 3332-:  |   0.00
# 3570-:  |   0.00
# 3808-:  |   0.00
# 4046-:  |   0.00
# 4284-:  |   0.00
# 4522-:  |   0.00
# 4760-:  |   0.00
# 4998-:  |   0.00
# 5236-:  |   0.00
# 5474-:  |   0.00
# 5712-:  |   1.00
#
# CPU times: user 4.38 s, sys: 52.1 ms, total: 4.43 s
# Wall time: 3.11 s
# Starting run with <class '_NetworKit.DorogovtsevMendesGenerator'>  and  65536 nodes
# CPU times: user 1.34 s, sys: 23.7 ms, total: 1.36 s
# Wall time: 1.37 s
# 3932157
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# <_NetworKit.PLM object at 0x7f430fc79270>
# Network Properties: G#10
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      1966080
# edges (m)                      3932157
# directed?                      False
# weighted?                      False
# isolated nodes                 0
# self-loops                     0
# density                        0.000002
# clustering coefficient         0.689264
# degeneracy (max. core number)  2
# -----------------------------  --------
# Node Degree Properties
# -------------------------  ---------------
# min. degree                2
# max. degree                204
# avg. degree                3.999997
# degree power law fit?      True, 10.023101
# degree power law exponent  1.2664
# degree assortativity       0.0489
# -------------------------  ---------------
# Path Structure
# -------------------------  --------
# connected components       1
# size of largest component  1966080
# estimated diameter range   (33, 34)
# -------------------------  --------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  800
#                                              modularity   0.996930
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇1822321.00
# 9-   :  ▇▇▇121619.00
# 18-  :  |16222.00
# 27-  :  |3861.00
# 36-  :  |1153.00
# 45-  :  | 486.00
# 54-  :  | 211.00
# 63-  :  |  79.00
# 72-  :  |  49.00
# 81-  :  |  38.00
# 90-  :  |  13.00
# 99-  :  |   6.00
# 108- :  |   5.00
# 117- :  |   4.00
# 126- :  |   6.00
# 135- :  |   1.00
# 144- :  |   1.00
# 153- :  |   3.00
# 162- :  |   0.00
# 171- :  |   1.00
# 180- :  |   0.00
# 189- :  |   0.00
# 198- :  |   1.00
# 207- :  |   0.00
# 216- :  |   0.00
#
# CPU times: user 29.6 s, sys: 284 ms, total: 29.9 s
# Wall time: 15.8 s
# Starting run with <class '_NetworKit.HyperbolicGenerator'>  and  65536 nodes
# CPU times: user 2.44 s, sys: 7.84 ms, total: 2.45 s
# Wall time: 1.16 s
# 3810766
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# <_NetworKit.PLM object at 0x7f430fc761f0>
# Network Properties: G#33
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65536
# edges (m)                      3810766
# directed?                      False
# weighted?                      False
# isolated nodes                 0
# self-loops                     0
# density                        0.001775
# clustering coefficient         0.790932
# degeneracy (max. core number)  82
# -----------------------------  --------
# Node Degree Properties
# -------------------------  ---------------
# min. degree                37
# max. degree                37693
# avg. degree                116.295349
# degree power law fit?      True, 16.431935
# degree power law exponent  1.4944
# degree assortativity       -0.0118
# -------------------------  ---------------
# Path Structure
# -------------------------  ------
# connected components       1
# size of largest component  65536
# estimated diameter range   (4, 4)
# -------------------------  ------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  25
#                                              modularity   0.906276
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇65441.00
# 1508-:  |  78.00
# 3016-:  |  11.00
# 4524-:  |   2.00
# 6032-:  |   2.00
# 7540-:  |   1.00
# 9048-:  |   0.00
# 10556-:  |   0.00
# 12064-:  |   0.00
# 13572-:  |   0.00
# 15080-:  |   0.00
# 16588-:  |   0.00
# 18096-:  |   0.00
# 19604-:  |   0.00
# 21112-:  |   0.00
# 22620-:  |   0.00
# 24128-:  |   0.00
# 25636-:  |   0.00
# 27144-:  |   0.00
# 28652-:  |   0.00
# 30160-:  |   0.00
# 31668-:  |   0.00
# 33176-:  |   0.00
# 34684-:  |   0.00
# 36192-:  |   1.00
#
# CPU times: user 14.1 s, sys: 132 ms, total: 14.3 s
# Wall time: 5.79 s
# Starting run with <class '_NetworKit.ChungLuGenerator'>  and  65536 nodes
# CPU times: user 33 s, sys: 32.4 ms, total: 33 s
# Wall time: 33.1 s
# 2753224
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# <_NetworKit.PLM object at 0x7f4334eac9f0>
# Network Properties: G#44
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65572
# edges (m)                      2753224
# directed?                      False
# weighted?                      False
# isolated nodes                 36889
# self-loops                     0
# density                        0.001281
# clustering coefficient         0.640928
# degeneracy (max. core number)  954
# -----------------------------  --------
# Node Degree Properties
# -------------------------  --------------
# min. degree                0
# max. degree                3997
# avg. degree                83.975599
# degree power law fit?      True, 3.501684
# degree power law exponent  1.8187
# degree assortativity       -0.2843
# -------------------------  --------------
# Path Structure
# -------------------------  ------
# connected components       36891
# size of largest component  28681
# estimated diameter range   (5, 6)
# -------------------------  ------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  36896
#                                              modularity   0.040275
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇60816.00
# 160- :  ▇1309.00
# 320- :  | 643.00
# 480- :  | 414.00
# 640- :  | 297.00
# 800- :  | 242.00
# 960- :  | 202.00
# 1120-:  | 208.00
# 1280-:  | 157.00
# 1440-:  | 150.00
# 1600-:  | 130.00
# 1760-:  | 118.00
# 1920-:  | 105.00
# 2080-:  |  84.00
# 2240-:  |  85.00
# 2400-:  |  70.00
# 2560-:  |  83.00
# 2720-:  |  68.00
# 2880-:  |  72.00
# 3040-:  |  69.00
# 3200-:  |  62.00
# 3360-:  |  52.00
# 3520-:  |  64.00
# 3680-:  |  42.00
# 3840-:  |  30.00
#
# CPU times: user 15.5 s, sys: 143 ms, total: 15.6 s
# Wall time: 7.33 s
# Starting run with <class '_NetworKit.BarabasiAlbertGenerator'>  and  65536 nodes
# CPU times: user 1min 16s, sys: 48.6 ms, total: 1min 16s
# Wall time: 1min 16s
# 3928619
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# <_NetworKit.PLM object at 0x7f42ea64e1f0>
# Network Properties: G#55
# ==================
# Basic Properties
# -----------------------------  --------
# nodes (n)                      65536
# edges (m)                      3928619
# directed?                      False
# weighted?                      False
# isolated nodes                 0
# self-loops                     0
# density                        0.001829
# clustering coefficient         0.009294
# degeneracy (max. core number)  60
# -----------------------------  --------
# Node Degree Properties
# -------------------------  ---------------
# min. degree                60
# max. degree                3373
# avg. degree                119.891937
# degree power law fit?      True, 16.216834
# degree power law exponent  1.5347
# degree assortativity       0.0013
# -------------------------  ---------------
# Path Structure
# -------------------------  ------
# connected components       1
# size of largest component  65536
# estimated diameter range   (3, 4)
# -------------------------  ------
# Community Structure
# -------------------------------------------  -----------  --------
# modularity-driven community detection (PLM)
#                                              communities  7
#                                              modularity   0.077115
# -------------------------------------------  -----------  --------
# Degree Distribution
# -------------------
# 0-   :  ▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇52326.00
# 135- :  ▇▇▇▇▇▇▇▇▇9839.00
# 270- :  ▇1833.00
# 405- :  | 636.00
# 540- :  | 295.00
# 675- :  | 176.00
# 810- :  | 107.00
# 945- :  |  77.00
# 1080-:  |  51.00
# 1215-:  |  44.00
# 1350-:  |  33.00
# 1485-:  |  32.00
# 1620-:  |  13.00
# 1755-:  |  10.00
# 1890-:  |   9.00
# 2025-:  |   8.00
# 2160-:  |   8.00
# 2295-:  |  11.00
# 2430-:  |   8.00
# 2565-:  |   5.00
# 2700-:  |   4.00
# 2835-:  |   2.00
# 2970-:  |   2.00
# 3105-:  |   4.00
# 3240-:  |   3.00
#
# CPU times: user 26.4 s, sys: 176 ms, total: 26.5 s
# Wall time: 13.3 s

# %%
deg_sum = 0
for j in range(0,len(degrees)):
    deg_sum += degrees[j]
    min_deg_sum = 0
    for i in range(j+1,len(degrees)):
        min_deg_sum += min(degrees[i], j+1)
    #print(deg_sum, ', ', min_deg_sum)
    if (deg_sum > (j+1) * j + min_deg_sum):
        print('Not realizable at', j, ', because ', deg_sum, ' > ', j+1,'*',j,' + ', min_deg_sum)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-19838d628e40> in <module>()
#       5     min_deg_sum = 0
#       6     for i in range(j+1,len(degrees)):
# ----> 7         min_deg_sum += min(degrees[i], j+1)
#       8     #print(deg_sum, ', ', min_deg_sum)
#       9     if (deg_sum > (j+1) * j + min_deg_sum):
#
# KeyboardInterrupt:
