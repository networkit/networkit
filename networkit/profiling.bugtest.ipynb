# %%
from networkit import *
# Out:
# 		<script type="text/javascript">
# 		<!--
#
# 		{
# 			var element = document.getElementById('NetworKit_script');
# 			if (element) {
# 				element.parentNode.removeChild(element);
# 			}
# 			element = document.createElement('script');
# 			element.type = 'text/javascript';
# ...

# %%
G = readGraph("/media/storage/NetworKit/input/PGPgiantcompo.graph", Format.METIS)

# %%
profiling.Profiling.setVerbose(True)

# %%
profiling.Profiling.getParallel()
# Out:
# 4

# %%
pf = profiling.Profiling.create(G)
# Out:
# ApproxBetweenness2:
# 2.22 s
# DegreeCentrality:
# 0.00 s
# KatzCentrality:
# 0.56 s
# CoreDecomposition:
# 0.10 s
# LocalClusteringCoefficient:
# 0.03 s
# KPathCentrality:
# 9.51 s
# PageRank:
# 1.24 s
#
# total time: 13.70 s

# %%
pf.show()
# Out:
# <!-- file: profiling.profiling.html author: Mark Erb This file contains all content representing the profiling layout All embraced terms will be automatically replaced by it's local representation in profiling.py : run(self) Some additional Tags and Attributes will be added while embedding => profiling.js --> <div class="NetworKit_Page" id="NetworKit_Page_0"> <div class="Group Node_Centrality_Measures"> <div class="Plot" title="ApproxBetweenness2" data-image="data:image/svg+xml;utf8,%3Csvg%20height%3D%22396pt%22%20version%3D%221.1%22%20viewBox%3D%220%200%20576%20396%22%20width%3D%22576pt%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%3E%20%3Cdefs%3E%20%3Cstyle%20type%3D%22text%2Fcss%22%3E%20%2A%7Bstroke-linecap%3Abutt%3Bstroke-linejoin%3Around%3B%7D%20%3C%2Fstyle%3E%20%3C%2Fdefs%3E%20%3Cg%20id%3D%22figure_1%22%3E%20%3Cg%20id%3D%22patch_1%22%3E%20%3Cpath%20d%3D%22%20M0%20396%20L576%20396%20L576%200%20L0%200%20z%20
# ...
